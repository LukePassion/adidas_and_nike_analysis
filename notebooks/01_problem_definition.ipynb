# %% [markdown]
# #ADIDAS VS NIKE
# **Análise de Mercado Baseado em Dados**

# %% [markdown]
# ##1. Contexto
#
# O mercado de artigos esportivos é altamente competitivo, com marcas globais disputando a preferência dos consumidores através de estratégias de preço, qualidade e posicionamento de marca.
#
# Entre essas marcas, Adidas e Nike se destacam como líderes do setor, oferecendo uma ampla variedade de produtos com diferentes faixas de preço, avaliações e estratégias promocionais.
#
# Este projeto tem como objetivo analisar dados de produtos dessas duas marcas, buscando identificar padrões de comportamento, diferenças estratégicas e percepções dos consumidores com base em preços, descontos e avaliações.

# %% [markdown]
# ##2. Pergunta Principal
# Quais são as principais diferenças entre Adidas e Nike em termos de preço, desconto, percepção do consumidor e posicionamento de marca, com base nos dados disponíveis?

# %% [markdown]
# ##3. Objetivos
# - Comparar os preços dos produtos entre Adidas e Nike
# - Analisar a distribuição de avaliações (ratings) por marca
# - Avaliar a relação entre desconto e avaliação
# - Identificar padrões de popularidade com base no número de reviews
# - Explorar possíveis diferenças no posicionamento de mercado entre as marcas

# %% [markdown]
# ##4. Carregamento dos Dados
#
# Os dados utilizados neste projeto já estão armazenados em uma tabela no ambiente Databricks, permitindo acesso direto e eficiente para análise.

# %%
#Carregamento dos Dados

df = spark.table("workspace.default.adidas_and_nike")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##6. Hipóteses iniciais
# - Produtos da Nike tendem a ter preços mais altos (posicionamento premium)
# - Adidas pode apresentar maior volume de produtos (estratégia de escala)
# - Produtos com maiores descontos podem ter avaliações mais baixas
# - Produtos com mais reviews tendem a ter avaliações mais confiáveis
# - Pode haver diferença na percepção do consumidor entre as marcas

# %% [markdown]
# ##7. Detalhe importante
# Observa-se um desbalanceamento na quantidade de produtos entre as marcas, com predominância de produtos da Adidas em relação à Nike. Esse fator será considerado e tratado durante a análise para evitar interpretações enviesadas.
